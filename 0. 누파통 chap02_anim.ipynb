# %% [markdown]
# # 1차원 데이터의 정리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plot_util import plot_var_interact, plot_std_interact

pd.set_option('display.precision', 3)
# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('../data/ch2_scores_em.csv', index_col='student number')
scores = np.array(df['english'])[:10]
scores
# Out:
# array([42, 69, 56, 41, 57, 48, 65, 49, 65, 58])

# %%
pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipywidgets) (8.10.0)
# Collecting widgetsnbextension~=4.0.7
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipywidgets) (6.19.2)
# Collecting jupyterlab-widgets~=3.0.7
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.2/198.2 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (22.0)
# Requirement already satisfied: tornado>=6.1 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: comm>=0.1.1 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: appnope in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.4)
# Requirement already satisfied: psutil in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: stack-data in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: backcall in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/haneul/anaconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /Users/haneul/anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/haneul/anaconda3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /Users/haneul/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/haneul/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in /Users/haneul/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: platformdirs>=2.5 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.5.2)
# Requirement already satisfied: six>=1.5 in /Users/haneul/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.0.6 jupyterlab-widgets-3.0.7 widgetsnbextension-4.0.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 그림 2.3 분산

# %%
plot_var_interact(scores[:4])
# Out:
# interactive(children=(IntSlider(value=42, description='A', min=1), IntSlider(value=69, description='B', min=1)…

# %% [markdown]
# ## 그림 2.4 표준편차

# %%
plot_std_interact(scores)
# Out:
# interactive(children=(IntSlider(value=42, description='A', min=1), IntSlider(value=69, description='B', min=1)…
